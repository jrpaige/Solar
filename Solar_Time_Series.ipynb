# %% [markdown]
# <b>random forest regressor</b> <br>
# OOB Score: 0.9806250796856056 <br>
# R-Squared on test: 0.9974039392381283<br>
# MSE: 0.01903015436936935
#
#
# OLS Linear Regression on cost per watt
# R-Squared score = 0.937
#
# OLS Linear Regression on weekly differences
# OLS Regression Results
# R-squared:	0.000

# %%
from src import Prep
from src.Time_Series_Helper_Funcs import *
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %reload_ext autoreload

# %%
# %autoreload

# %%
df = Prep.prep()
# Out:
# 1 of 11 |    Reading in first dataset.
#              Using 4/60 features/columns: 'Installation Date', 'System Size', 'Total Installed Price' , 'Customer Segment'
#              Changing -9999 values to null
# 2 of 11 |    Reading in second dataset.
#              Using 4/60 features/columns: 'Installation Date', 'System Size', 'Total Installed Price' , 'Customer Segment'
#              Changing -9999 values to null
# 3 of 11 |    Concatenating datasets together
# 4 of 11 |    Cleaning up column names
# 5 of 11 |    Sorting values by installation_date
# 6 of 11 |    Assigning installation_date as index
# 7 of 11 |    Refining to only RES customer_segment
# 8 of 11 |    Replacing all null values with median values from same year
# 9 of 11 |    Adusting prices for inflation
# 10 of 11|    Creating target variable: cost_per_watt
# 11 of 11|    Removing > 1600 outliers above $25 per watt
# Prep complete
#  ------------------------------------------------------------

# %% [markdown]
# ## SHORTEND TIMELINE

# %%
shortened_timeline()
# Out:
#                    cost_per_watt
# installation_date
# 2002-01-06                12.935
# 2002-01-13                12.670
# 2002-01-20                12.110
# 2002-01-27                11.950
# 2002-02-03                11.820
# ...                          ...
# 2018-12-09                 3.790
# 2018-12-16                 3.850
# 2018-12-23                 3.890
# 2018-12-30                 3.850
# 2019-01-06                 3.900
#
# [888 rows x 1 columns]

# %%
syw, s_lagg = shortened_timeline(df)[0], shortened_timeline(df)[1]
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.983
# Model:                            OLS   Adj. R-squared:                  0.983
# Method:                 Least Squares   F-statistic:                 1.737e+04
# Date:                Fri, 13 Mar 2020   Prob (F-statistic):               0.00
# Time:                        15:13:52   Log-Likelihood:                -320.64
# No. Observations:                 885   AIC:                             649.3
# Df Residuals:                     881   BIC:                             668.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0235      0.035      0.676      0.499      -0.045       0.092
# Lag1           0.3002      0.031      9.805      0.000       0.240       0.360
# Lag2           0.2809      0.031      9.112      0.000       0.220       0.341
# Lag3           0.4130      0.031     13.508      0.000       0.353       0.473
# ==============================================================================
# Omnibus:                      416.592   Durbin-Watson:                   2.179
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            20896.855
# Skew:                           1.370   Prob(JB):                         0.00
# Kurtosis:                      26.647   Cond. No.                         44.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.983
# Model:                            OLS   Adj. R-squared:                  0.983
# Method:                 Least Squares   F-statistic:                 1.737e+04
# Date:                Fri, 13 Mar 2020   Prob (F-statistic):               0.00
# Time:                        15:13:53   Log-Likelihood:                -320.64
# No. Observations:                 885   AIC:                             649.3
# Df Residuals:                     881   BIC:                             668.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0235      0.035      0.676      0.499      -0.045       0.092
# Lag1           0.3002      0.031      9.805      0.000       0.240       0.360
# Lag2           0.2809      0.031      9.112      0.000       0.220       0.341
# Lag3           0.4130      0.031     13.508      0.000       0.353       0.473
# ==============================================================================
# Omnibus:                      416.592   Durbin-Watson:                   2.179
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            20896.855
# Skew:                           1.370   Prob(JB):                         0.00
# Kurtosis:                      26.647   Cond. No.                         44.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
compute_autocorrelation(s_lagg)
# Out:
# -0.3134774974809724

# %%
rolling_plot(syw)

test_stationarity(syw)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.323589
# p-value                          0.618312
# #Lags Used                      21.000000
# Number of Observations Used    866.000000
# Critical Value (1%)             -3.437924
# Critical Value (5%)             -2.864883
# Critical Value (10%)            -2.568550
# dtype: float64

# %%
box_jenkins_plot(syw)

# %%
#shortened timeline 
get_differences(syw)
# Out:
# ADF p-value: 0.00
# Achieved stationarity! Reject ADF H0.
#                    cost_per_watt
# installation_date
# 2002-01-06                   NaN
# 2002-01-13                -0.265
# 2002-01-20                -0.560
# 2002-01-27                -0.160
# 2002-02-03                -0.130
# ...                          ...
# 2018-12-09                 0.010
# 2018-12-16                 0.060
# 2018-12-23                 0.040
# 2018-12-30                -0.040
# 2019-01-06                 0.050
#
# [888 rows x 1 columns]

# %%
w_diff = weekly_differences.dropna()

# %%
s_lagg_cost = create_lag(weekly_differences)

# %%
compute_autocorrelation(s_lagg_cost)
# Out:
# -0.7809776370435969

# %%
plot_ac_scat(w_diff)

# %%
s_linear_model, s_linear_trend = linear_model_trend(syw)[0], linear_model_trend(syw)[1]

# %%
s_linear_model, s_linear_trend = linear_model_trend(syw)[0], linear_model_trend(syw)[1]

# %%
print('r squared for linear model on price', s_linear_model.rsquared)
print('mse total for linear model on price', s_linear_model.mse_total)
print('r squared for linear model on price', s_linear_model.summary)
# Out:
# r squared for linear model on price 0.9368391801743174
# mse total for linear model on price 7.338660621388017
# r squared for linear model on price <bound method RegressionResults.summary of <statsmodels.regression.linear_model.OLSResults object at 0x1774d0890>>

# %%
OLS linear

# %%
s_linear_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          cost_per_watt   R-squared:                       0.937
# Model:                            OLS   Adj. R-squared:                  0.937
# Method:                 Least Squares   F-statistic:                 1.314e+04
# Date:                Fri, 13 Mar 2020   Prob (F-statistic):               0.00
# Time:                        15:31:04   Log-Likelihood:                -918.12
# No. Observations:                 888   AIC:                             1840.
# Df Residuals:                     886   BIC:                             1850.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         12.0522      0.046    263.390      0.000      11.962      12.142
# x1            -0.0102   8.92e-05   -114.637      0.000      -0.010      -0.010
# ==============================================================================
# Omnibus:                        4.833   Durbin-Watson:                   0.417
# Prob(Omnibus):                  0.089   Jarque-Bera (JB):                4.901
# Skew:                           0.179   Prob(JB):                       0.0862
# Kurtosis:                       2.932   Cond. No.                     1.03e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.03e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
diff_linear_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          cost_per_watt   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                   0.05783
# Date:                Fri, 13 Mar 2020   Prob (F-statistic):              0.810
# Time:                        15:33:00   Log-Likelihood:                -530.05
# No. Observations:                 887   AIC:                             1064.
# Df Residuals:                     885   BIC:                             1074.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0164      0.030     -0.553      0.581      -0.074       0.042
# x1          1.389e-05   5.77e-05      0.240      0.810   -9.94e-05       0.000
# ==============================================================================
# Omnibus:                      274.843   Durbin-Watson:                   2.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            15107.376
# Skew:                          -0.554   Prob(JB):                         0.00
# Kurtosis:                      23.188   Cond. No.                     1.03e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.03e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
s_linear_model, s_linear_trend = linear_model_trend(syw)[0], linear_model_trend(syw)[1]

# %%
diff_linear_model, diff_linear_trend = linear_model_trend(w_diff)[0], linear_model_trend(w_diff)[1]

# %% [raw]
# test statistic  = -6.775242807488729
# pvalue          = 2.580702530296343e-09
# usedlag         = 21
# nobs            = 865
# crit value 1%   = -3.4379324415517494
# crit value 5%   = -2.864887107873992
# crit value 10%  = -2.568552251328143
# icbest          = 263.3248215755807

# %% [markdown]
# Even though test statistic and critical value are not near equal, we only care about pvalue which determines if we can reject the null hypothesis of the ADF test.

# %%
looking at the lags involved

# %%
d = weekly differences
p = pational autocorrelation
q = autocorrelation

# %%
wd = np.array(weekly_differences)
sywa = np.array(syw)

# %%
auto_arima(wd[1:]).order
# Out:
# (4, 0, 3)

# %%
random_forest_model(syw)
# Out:
# OOB Score: 0.9806250796856056
# r2 score on test: 0.9974039392381283
# MSE: 0.01903015436936935
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# [CV] RFR__max_depth=5, RFR__n_estimators=5 ...........................
# [CV] ............ RFR__max_depth=5, RFR__n_estimators=5, total=   0.0s
# [CV] RFR__max_depth=5, RFR__n_estimators=5 ...........................
# [CV] ............ RFR__max_depth=5, RFR__n_estimators=5, total=   0.0s
# [CV] RFR__max_depth=5, RFR__n_estimators=5 ...........................
# [CV] ............ RFR__max_depth=5, RFR__n_estimators=5, total=   0.0s
# [CV] RFR__max_depth=5, RFR__n_estimators=10 ..........................
# [CV] ........... RFR__max_depth=5, RFR__n_estimators=10, total=   0.0s
# [CV] RFR__max_depth=5, RFR__n_estimators=10 ..........................
# [CV] ........... RFR__max_depth=5, RFR__n_estimators=10, total=   0.0s
# [CV] RFR__max_depth=5, RFR__n_estimators=10 ..........................
# [CV] ........... RFR__max_depth=5, RFR__n_estimators=10, total=   0.0s
# [CV] RFR__max_depth=5, RFR__n_estimators=15 ..........................
# [CV] ........... RFR__max_depth=5, RFR__n_estimators=15, total=   0.0s
# [CV] RFR__max_depth=5, RFR__n_estimators=15 ..........................
# [CV] ........... RFR__max_depth=5, RFR__n_estimators=15, total=   0.0s
# [CV] RFR__max_depth=5, RFR__n_estimators=15 ..........................
# [CV] ........... RFR__max_depth=5, RFR__n_estimators=15, total=   0.0s
# [CV] RFR__max_depth=5, RFR__n_estimators=20 ..........................
# [CV] ........... RFR__max_depth=5, RFR__n_estimators=20, total=   0.0s
# [CV] RFR__max_depth=5, RFR__n_estimators=20 ..........................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [CV] ........... RFR__max_depth=5, RFR__n_estimators=20, total=   0.0s
# [CV] RFR__max_depth=5, RFR__n_estimators=20 ..........................
# [CV] ........... RFR__max_depth=5, RFR__n_estimators=20, total=   0.0s
# [CV] RFR__max_depth=10, RFR__n_estimators=5 ..........................
# [CV] ........... RFR__max_depth=10, RFR__n_estimators=5, total=   0.0s
# [CV] RFR__max_depth=10, RFR__n_estimators=5 ..........................
# [CV] ........... RFR__max_depth=10, RFR__n_estimators=5, total=   0.0s
# [CV] RFR__max_depth=10, RFR__n_estimators=5 ..........................
# [CV] ........... RFR__max_depth=10, RFR__n_estimators=5, total=   0.0s
# [CV] RFR__max_depth=10, RFR__n_estimators=10 .........................
# [CV] .......... RFR__max_depth=10, RFR__n_estimators=10, total=   0.0s
# [CV] RFR__max_depth=10, RFR__n_estimators=10 .........................
# [CV] .......... RFR__max_depth=10, RFR__n_estimators=10, total=   0.0s
# [CV] RFR__max_depth=10, RFR__n_estimators=10 .........................
# [CV] .......... RFR__max_depth=10, RFR__n_estimators=10, total=   0.0s
# [CV] RFR__max_depth=10, RFR__n_estimators=15 .........................
# [CV] .......... RFR__max_depth=10, RFR__n_estimators=15, total=   0.0s
# [CV] RFR__max_depth=10, RFR__n_estimators=15 .........................
# [CV] .......... RFR__max_depth=10, RFR__n_estimators=15, total=   0.0s
# [CV] RFR__max_depth=10, RFR__n_estimators=15 .........................
# [CV] .......... RFR__max_depth=10, RFR__n_estimators=15, total=   0.0s
# [CV] RFR__max_depth=10, RFR__n_estimators=20 .........................
# [CV] .......... RFR__max_depth=10, RFR__n_estimators=20, total=   0.0s
# [CV] RFR__max_depth=10, RFR__n_estimators=20 .........................
# [CV] .......... RFR__max_depth=10, RFR__n_estimators=20, total=   0.0s
# [CV] RFR__max_depth=10, RFR__n_estimators=20 .........................
# [CV] .......... RFR__max_depth=10, RFR__n_estimators=20, total=   0.0s
# [CV] RFR__max_depth=15, RFR__n_estimators=5 ..........................
# [CV] ........... RFR__max_depth=15, RFR__n_estimators=5, total=   0.0s
# [CV] RFR__max_depth=15, RFR__n_estimators=5 ..........................
# [CV] ........... RFR__max_depth=15, RFR__n_estimators=5, total=   0.0s
# [CV] RFR__max_depth=15, RFR__n_estimators=5 ..........................
# [CV] ........... RFR__max_depth=15, RFR__n_estimators=5, total=   0.0s
# [CV] RFR__max_depth=15, RFR__n_estimators=10 .........................
# [CV] .......... RFR__max_depth=15, RFR__n_estimators=10, total=   0.0s
# [CV] RFR__max_depth=15, RFR__n_estimators=10 .........................
# [CV] .......... RFR__max_depth=15, RFR__n_estimators=10, total=   0.0s
# [CV] RFR__max_depth=15, RFR__n_estimators=10 .........................
# [CV] .......... RFR__max_depth=15, RFR__n_estimators=10, total=   0.0s
# [CV] RFR__max_depth=15, RFR__n_estimators=15 .........................
# [CV] .......... RFR__max_depth=15, RFR__n_estimators=15, total=   0.0s
# [CV] RFR__max_depth=15, RFR__n_estimators=15 .........................
# [CV] .......... RFR__max_depth=15, RFR__n_estimators=15, total=   0.0s
# [CV] RFR__max_depth=15, RFR__n_estimators=15 .........................
# [CV] .......... RFR__max_depth=15, RFR__n_estimators=15, total=   0.0s
# [CV] RFR__max_depth=15, RFR__n_estimators=20 .........................
# [CV] .......... RFR__max_depth=15, RFR__n_estimators=20, total=   0.0s
# [CV] RFR__max_depth=15, RFR__n_estimators=20 .........................
# [CV] .......... RFR__max_depth=15, RFR__n_estimators=20, total=   0.0s
# [CV] RFR__max_depth=15, RFR__n_estimators=20 .........................
# [CV] .......... RFR__max_depth=15, RFR__n_estimators=20, total=   0.0s
# [CV] RFR__max_depth=20, RFR__n_estimators=5 ..........................
# [CV] ........... RFR__max_depth=20, RFR__n_estimators=5, total=   0.0s
# [CV] RFR__max_depth=20, RFR__n_estimators=5 ..........................
# [CV] ........... RFR__max_depth=20, RFR__n_estimators=5, total=   0.0s
# [CV] RFR__max_depth=20, RFR__n_estimators=5 ..........................
# [CV] ........... RFR__max_depth=20, RFR__n_estimators=5, total=   0.0s
# [CV] RFR__max_depth=20, RFR__n_estimators=10 .........................
# [CV] .......... RFR__max_depth=20, RFR__n_estimators=10, total=   0.0s
# [CV] RFR__max_depth=20, RFR__n_estimators=10 .........................
# [CV] .......... RFR__max_depth=20, RFR__n_estimators=10, total=   0.0s
# [CV] RFR__max_depth=20, RFR__n_estimators=10 .........................
# [CV] .......... RFR__max_depth=20, RFR__n_estimators=10, total=   0.0s
# [CV] RFR__max_depth=20, RFR__n_estimators=15 .........................
# [CV] .......... RFR__max_depth=20, RFR__n_estimators=15, total=   0.0s
# [CV] RFR__max_depth=20, RFR__n_estimators=15 .........................
# [CV] .......... RFR__max_depth=20, RFR__n_estimators=15, total=   0.0s
# [CV] RFR__max_depth=20, RFR__n_estimators=15 .........................
# [CV] .......... RFR__max_depth=20, RFR__n_estimators=15, total=   0.0s
# [CV] RFR__max_depth=20, RFR__n_estimators=20 .........................
# [CV] .......... RFR__max_depth=20, RFR__n_estimators=20, total=   0.0s
# [CV] RFR__max_depth=20, RFR__n_estimators=20 .........................
# [CV] .......... RFR__max_depth=20, RFR__n_estimators=20, total=   0.0s
# [CV] RFR__max_depth=20, RFR__n_estimators=20 .........................
# [CV] .......... RFR__max_depth=20, RFR__n_estimators=20, total=   0.0s
# Best parameters: {'RFR__max_depth': 5, 'RFR__n_estimators': 10}
# test R squared: 0.988485889855694
# [Parallel(n_jobs=1)]: Done  48 out of  48 | elapsed:    1.0s finished
# {'mean_fit_time': array([0.00902502, 0.01227204, 0.01474245, 0.02096232, 0.008346  ,
#         0.01131662, 0.01849532, 0.02603428, 0.00638739, 0.01309896,
#         0.01762295, 0.02333673, 0.00654642, 0.01172678, 0.02030969,
#         0.02441462]),
#  'std_fit_time': array([8.70770332e-04, 1.39005692e-03, 8.24331639e-05, 1.30048195e-03,
#         6.47170017e-04, 1.20709254e-04, 1.51242217e-03, 1.53693205e-03,
#         1.69243869e-04, 4.71576882e-04, 8.53429442e-04, 1.84029730e-03,
#         1.28229059e-04, 1.19323887e-04, 2.84950306e-03, 2.11684032e-03]),
#  'mean_score_time': array([0.00216921, 0.00185331, 0.00181635, 0.00228429, 0.00180093,
#         0.00170366, 0.00239507, 0.00313663, 0.00144887, 0.00255179,
#         0.00271694, 0.002467  , 0.00147986, 0.001755  , 0.00302021,
#         0.0024728 ]),
#  'std_score_time': array([2.88349790e-04, 2.03192723e-04, 2.11681448e-05, 2.16803738e-04,
#         9.22767858e-05, 7.56037140e-06, 3.55663272e-04, 1.04391084e-03,
#         3.10499964e-05, 8.91523359e-04, 8.42256262e-04, 3.33891598e-04,
#         9.28506966e-06, 8.74707047e-06, 8.34768384e-04, 2.30777389e-04]),
#  'param_RFR__max_depth': masked_array(data=[5, 5, 5, 5, 10, 10, 10, 10, 15, 15, 15, 15, 20, 20, 20,
#                     20],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_RFR__n_estimators': masked_array(data=[5, 10, 15, 20, 5, 10, 15, 20, 5, 10, 15, 20, 5, 10, 15,
#                     20],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'RFR__max_depth': 5, 'RFR__n_estimators': 5},
#   {'RFR__max_depth': 5, 'RFR__n_estimators': 10},
#   {'RFR__max_depth': 5, 'RFR__n_estimators': 15},
#   {'RFR__max_depth': 5, 'RFR__n_estimators': 20},
#   {'RFR__max_depth': 10, 'RFR__n_estimators': 5},
#   {'RFR__max_depth': 10, 'RFR__n_estimators': 10},
#   {'RFR__max_depth': 10, 'RFR__n_estimators': 15},
#   {'RFR__max_depth': 10, 'RFR__n_estimators': 20},
#   {'RFR__max_depth': 15, 'RFR__n_estimators': 5},
#   {'RFR__max_depth': 15, 'RFR__n_estimators': 10},
#   {'RFR__max_depth': 15, 'RFR__n_estimators': 15},
#   {'RFR__max_depth': 15, 'RFR__n_estimators': 20},
#   {'RFR__max_depth': 20, 'RFR__n_estimators': 5},
#   {'RFR__max_depth': 20, 'RFR__n_estimators': 10},
#   {'RFR__max_depth': 20, 'RFR__n_estimators': 15},
#   {'RFR__max_depth': 20, 'RFR__n_estimators': 20}],
#  'split0_test_score': array([0.9748931 , 0.97601867, 0.97459643, 0.97467813, 0.97449091,
#         0.97536807, 0.97625795, 0.9745397 , 0.9742999 , 0.97451948,
#         0.97542724, 0.97526011, 0.97369155, 0.97476871, 0.97549641,
#         0.97539429]),
#  'split1_test_score': array([0.98049607, 0.98320871, 0.98049935, 0.98223899, 0.96853183,
#         0.97438728, 0.97790375, 0.9756751 , 0.97612046, 0.97456767,
#         0.97353443, 0.97568119, 0.974756  , 0.97760606, 0.97702213,
#         0.97479928]),
#  'split2_test_score': array([0.98576393, 0.98467889, 0.98563855, 0.98651553, 0.98384449,
#         0.98024621, 0.98047393, 0.9841581 , 0.97995518, 0.98244543,
#         0.98269494, 0.98343615, 0.97977284, 0.97738414, 0.98262423,
#         0.9804434 ]),
#  'mean_test_score': array([0.98038437, 0.98130209, 0.98024478, 0.98114422, 0.97562241,
#         0.97666718, 0.97821188, 0.9781243 , 0.97679185, 0.97717753,
#         0.97721887, 0.97812582, 0.97607346, 0.9765863 , 0.97838092,
#         0.97687899]),
#  'std_test_score': array([0.0044387 , 0.00378385, 0.00451152, 0.00489421, 0.00630236,
#         0.00256223, 0.0017349 , 0.00429165, 0.00235707, 0.00372502,
#         0.00394851, 0.0037589 , 0.0026517 , 0.00128842, 0.00306444,
#         0.00253209]),
#  'rank_test_score': array([ 3,  1,  4,  2, 16, 13,  6,  8, 12, 10,  9,  7, 15, 14,  5, 11],
#        dtype=int32),
#  'split0_train_score': array([0.99060055, 0.99084071, 0.9914755 , 0.9914408 , 0.99589159,
#         0.99628494, 0.99621232, 0.99725392, 0.99686018, 0.99653994,
#         0.99724746, 0.99714417, 0.99568145, 0.99751439, 0.9971511 ,
#         0.9974508 ]),
#  'split1_train_score': array([0.98849879, 0.98896513, 0.98909804, 0.99012484, 0.99511706,
#         0.9965446 , 0.99586708, 0.99664386, 0.99473062, 0.99694235,
#         0.99712536, 0.99678068, 0.9951756 , 0.99460351, 0.99668947,
#         0.99610477]),
#  'split2_train_score': array([0.98914438, 0.98862528, 0.98881602, 0.98857089, 0.99402485,
#         0.99527211, 0.99533484, 0.99576107, 0.99574003, 0.99521866,
#         0.99474108, 0.99634493, 0.99470211, 0.99613138, 0.99529594,
#         0.99667067]),
#  'mean_train_score': array([0.98941457, 0.98947704, 0.98979652, 0.99004551, 0.99501116,
#         0.99603388, 0.99580475, 0.99655295, 0.99577694, 0.99623365,
#         0.9963713 , 0.99675659, 0.99518639, 0.99608309, 0.99637883,
#         0.99674208]),
#  'std_train_score': array([0.00087906, 0.00097419, 0.00119279, 0.00117298, 0.00076576,
#         0.00054898, 0.00036093, 0.00061283, 0.00086978, 0.00073627,
#         0.00115382, 0.00032673, 0.00039989, 0.00118885, 0.00078857,
#         0.00055183])}
