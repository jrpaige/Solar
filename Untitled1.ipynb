# %%
from src.Prep import *
from src.Model import *
import warnings
warnings.filterwarnings('ignore')

# %load_ext autoreload
# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = Prep().compile()
# Out:
# ------------------------------------PREP------------------------------------
#  1 of 11 |    Reading in data
#          |    Filtering to 4 features:
#          |       Date, System Size, Total Cost, Customer Segment
#          |    Changing -9999 values to null
#  2 of 11 |    Cleaning up column names
#  3 of 11 |    Refining to only RES Customer Segment
#  4 of 11 |    Sorting values by installation_date
#          |    Assigning installation_date as index
#  5 of 11 |    Replacing all null values with median values from same year
#  6 of 11 |    Adusting prices for inflation
#  7 of 11 |    Creating target variable: cost_per_watt
#  8 of 11 |    Resampling data into weekly medians
#          |    Cropping dataframe to keep only continuous non-null data
#  9 of 11 |    Testing for stationarity
#          |       ADF P-value: 0.9587
#          |       Time Series is not stationary.
#          |       Fail to reject ADF H0
# ...

# %%
#predetermined order as default
Model().show_model(df)

# %%
#auto_arima as order method
Model(order_method='auto').show_model(df)
# Out:
# ---------------------------------------------------------------------------
# TerminatedWorkerError                     Traceback (most recent call last)
# <ipython-input-5-d3fb320b9ec9> in <module>
#       1 #auto_arima as order method
# ----> 2 Model(order_method='auto').show_model(df)
#
# ~/code/DSI/getit/Solar/src/Model.py in show_model(self, df)
#     421
#     422     def show_model(self,df):
# --> 423         return self.all_models(df)
#     424
#     425 if __name__ == "__main__":
#
# ~/code/DSI/getit/Solar/src/Model.py in all_models(self, df)
#     378         '''
#     379         y_preds, y_train, [train_s, train_e, pred_s, pred_e], model_type = self.regression(df)
# --> 380         res, atrain, atest, arima_title, a_pred, order = self.ARIMA_predict(df)
#     381         RandomForest_resid, OLS_lin_resid, OLS_resid = self.regressor_resids(df)
#     382         resid_list = [res.resid,RandomForest_resid, OLS_lin_resid, OLS_resid]
#
# ...

# %%
#user selected for order 
Model(order_method='select').show_model(df)

# %%
#Second order differenced as input df and user selected order  
Model(order_method='select').show_model(df.diff().dropna())

# %%
#Manual Order Method confirmed 
Model(order_method='manual').show_model(df)
